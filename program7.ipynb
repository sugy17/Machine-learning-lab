# %%
from pgmpy.models import BayesianModel

# %%
cancer_model = BayesianModel([("Pollution", "Cancer"),("Smoker", "Cancer"),("Cancer", "Xray"),("Cancer", "Dyspnoea")])

print(cancer_model)

# %%
cancer_model.nodes()
# Out:
# NodeView(('Pollution', 'Cancer', 'Smoker', 'Xray', 'Dyspnoea'))

# %%
cancer_model.edges()
# Out:
# OutEdgeView([('Pollution', 'Cancer'), ('Cancer', 'Xray'), ('Cancer', 'Dyspnoea'), ('Smoker', 'Cancer')])

# %%
cancer_model.get_cpds()
# Out:
# []

# %%
from pgmpy.factors.discrete import TabularCPD

# %%
cpd_poll = TabularCPD(variable="Pollution",variable_card=2,values=[[0.9],[0.1]])
cpd_smoke = TabularCPD(variable="Smoker",variable_card=2,values=[[0.3],[0.7]])
cpd_cancer = TabularCPD(variable="Cancer",variable_card=2,values=[[0.03, 0.05, 0.001, 0.02],[0.97, 0.95, 0.999, 0.98]],evidence=["Smoker", "Pollution"],evidence_card=[2, 2])
cpd_xray = TabularCPD(variable="Xray",variable_card=2,values=[[0.9, 0.2],[0.1, 0.8]],evidence=["Cancer"],evidence_card=[2])
cpd_dysp = TabularCPD(variable="Dyspnoea",variable_card=2,values=[[0.65, 0.3],[0.35, 0.7]],evidence=["Cancer"],evidence_card=[2])
cancer_model.add_cpds(cpd_poll, cpd_smoke, cpd_cancer, cpd_xray, cpd_dysp)
cancer_model.check_model()
# Out:
# True

# %%
cancer_model.is_active_trail("Pollution", "Smoker")
# Out:
# False

# %%
cancer_model.is_active_trail("Pollution", "Smoker", observed=["Cancer"])
# Out:
# True

# %%
cancer_model.get_cpds()
# Out:
# [<TabularCPD representing P(Pollution:2) at 0x2072d13ddc0>,
#  <TabularCPD representing P(Smoker:2) at 0x2072d13dd00>,
#  <TabularCPD representing P(Cancer:2 | Smoker:2, Pollution:2) at 0x20726d32820>,
#  <TabularCPD representing P(Xray:2 | Cancer:2) at 0x2072cfeb1f0>,
#  <TabularCPD representing P(Dyspnoea:2 | Cancer:2) at 0x20726d321f0>]

# %%
print(cancer_model.get_cpds("Pollution"))
# Out:
# +--------------+-----+
# | Pollution(0) | 0.9 |
# +--------------+-----+
# | Pollution(1) | 0.1 |
# +--------------+-----+

# %%
print(cancer_model.get_cpds("Smoker"))
# Out:
# +-----------+-----+
# | Smoker(0) | 0.3 |
# +-----------+-----+
# | Smoker(1) | 0.7 |
# +-----------+-----+

# %%
print(cancer_model.get_cpds("Xray"))
# Out:
# +---------+-----------+-----------+
# | Cancer  | Cancer(0) | Cancer(1) |
# +---------+-----------+-----------+
# | Xray(0) | 0.9       | 0.2       |
# +---------+-----------+-----------+
# | Xray(1) | 0.1       | 0.8       |
# +---------+-----------+-----------+

# %%
print(cancer_model.get_cpds("Dyspnoea"))
# Out:
# +-------------+-----------+-----------+
# | Cancer      | Cancer(0) | Cancer(1) |
# +-------------+-----------+-----------+
# | Dyspnoea(0) | 0.65      | 0.3       |
# +-------------+-----------+-----------+
# | Dyspnoea(1) | 0.35      | 0.7       |
# +-------------+-----------+-----------+

# %%
print(cancer_model.get_cpds("Cancer"))
# Out:
# +-----------+--------------+--------------+--------------+--------------+
# | Smoker    | Smoker(0)    | Smoker(0)    | Smoker(1)    | Smoker(1)    |
# +-----------+--------------+--------------+--------------+--------------+
# | Pollution | Pollution(0) | Pollution(1) | Pollution(0) | Pollution(1) |
# +-----------+--------------+--------------+--------------+--------------+
# | Cancer(0) | 0.03         | 0.05         | 0.001        | 0.02         |
# +-----------+--------------+--------------+--------------+--------------+
# | Cancer(1) | 0.97         | 0.95         | 0.999        | 0.98         |
# +-----------+--------------+--------------+--------------+--------------+

# %%
cancer_model.local_independencies("Xray")
# Out:
# (Xray _|_ Pollution, Smoker, Dyspnoea | Cancer)

# %%
cancer_model.local_independencies("Pollution")
# Out:
# (Pollution _|_ Smoker)

# %%
cancer_model.local_independencies("Smoker")
# Out:
# (Smoker _|_ Pollution)

# %%
cancer_model.local_independencies("Dyspnoea")
# Out:
# (Dyspnoea _|_ Pollution, Smoker, Xray | Cancer)

# %%
cancer_model.local_independencies("Cancer")

# %%
cancer_model.get_independencies()
# Out:
# (Pollution _|_ Smoker)
# (Pollution _|_ Xray, Dyspnoea | Cancer)
# (Pollution _|_ Xray, Dyspnoea | Smoker, Cancer)
# (Pollution _|_ Xray | Dyspnoea, Cancer)
# (Pollution _|_ Dyspnoea | Xray, Cancer)
# (Pollution _|_ Xray | Smoker, Dyspnoea, Cancer)
# (Pollution _|_ Dyspnoea | Smoker, Cancer, Xray)
# (Smoker _|_ Pollution)
# (Smoker _|_ Xray, Dyspnoea | Cancer)
# (Smoker _|_ Xray, Dyspnoea | Pollution, Cancer)
# (Smoker _|_ Dyspnoea | Xray, Cancer)
# (Smoker _|_ Xray | Dyspnoea, Cancer)
# (Smoker _|_ Dyspnoea | Pollution, Xray, Cancer)
# (Smoker _|_ Xray | Pollution, Dyspnoea, Cancer)
# (Xray _|_ Pollution, Smoker, Dyspnoea | Cancer)
# (Xray _|_ Smoker, Dyspnoea | Pollution, Cancer)
# (Xray _|_ Pollution, Dyspnoea | Smoker, Cancer)
# (Xray _|_ Pollution, Smoker | Dyspnoea, Cancer)
# (Xray _|_ Dyspnoea | Pollution, Smoker, Cancer)
# (Xray _|_ Smoker | Pollution, Dyspnoea, Cancer)
# (Xray _|_ Pollution | Smoker, Dyspnoea, Cancer)
# (Dyspnoea _|_ Pollution, Smoker, Xray | Cancer)
# (Dyspnoea _|_ Smoker, Xray | Pollution, Cancer)
# (Dyspnoea _|_ Pollution, Xray | Smoker, Cancer)
# (Dyspnoea _|_ Pollution, Smoker | Xray, Cancer)
# (Dyspnoea _|_ Xray | Pollution, Smoker, Cancer)
# (Dyspnoea _|_ Smoker | Pollution, Xray, Cancer)
# (Dyspnoea _|_ Pollution | Smoker, Cancer, Xray)

# %%
from pgmpy.inference import VariableElimination

# %%
cancer_infr = VariableElimination(cancer_model)

# %%
q = cancer_infr.query(variables=["Cancer"], evidence={"Smoker": 1})
print(q)
# Out:
# Finding Elimination Order: : 100%|██████████| 3/3 [00:00<00:00, 1503.87it/s]
# Eliminating: Dyspnoea: 100%|██████████| 3/3 [00:00<00:00, 376.00it/s]
# +-----------+---------------+
# | Cancer    |   phi(Cancer) |
# +===========+===============+
# | Cancer(0) |        0.0029 |
# +-----------+---------------+
# | Cancer(1) |        0.9971 |
# +-----------+---------------+

# %%
q = cancer_infr.query(variables=["Cancer"], evidence={"Smoker": 1, "Pollution": 1})
print(q)
# Out:
# Finding Elimination Order: : 100%|██████████| 2/2 [00:00<00:00, 1003.78it/s]
# Eliminating: Dyspnoea: 100%|██████████| 2/2 [00:00<00:00, 501.62it/s]
# +-----------+---------------+
# | Cancer    |   phi(Cancer) |
# +===========+===============+
# | Cancer(0) |        0.0200 |
# +-----------+---------------+
# | Cancer(1) |        0.9800 |
# +-----------+---------------+

# %% [markdown]
# # extra code

# %%
import numpy as np
from urllib.request import urlopen
import urllib
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl
import pandas as pd

# %%
data= "http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data"

# %%
names = ["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal", "heartdisease"]

# %%
heartDisease = pd.read_csv(urlopen(data), names=names)
heartDisease.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  heartdisease
# 0    ?             0
# 1    ?             0
# 2    ?             0
# 3    6             0
# 4    ?             0

# %%
del heartDisease["ca"]
del heartDisease["slope"]
del heartDisease["thal"]
del heartDisease["oldpeak"]

# %%
heartDisease = heartDisease.replace("?", np.nan)
heartDisease.dtypes
# Out:
# age              int64
# sex              int64
# cp               int64
# trestbps        object
# chol            object
# fbs             object
# restecg         object
# thalach         object
# exang           object
# heartdisease     int64
# dtype: object

# %%
heartDisease.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'heartdisease'],
#       dtype='object')

# %%
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator

# %%
model = BayesianModel([("age", "trestbps"),("age", "fbs"),("sex", "trestbps"),("sex", "trestbps"),("exang", "trestbps"),("trestbps", "heartdisease"),("fbs", "heartdisease"),("heartdisease", "restecg"),("heartdisease", "thalach"),("heartdisease", "thalach"),("heartdisease", "chol")])

# %%
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
print(model.get_cpds("age"))
# Out:
# +---------+------------+
# | age(28) | 0.00383142 |
# +---------+------------+
# | age(29) | 0.00383142 |
# +---------+------------+
# | age(30) | 0.00383142 |
# +---------+------------+
# | age(31) | 0.00766284 |
# +---------+------------+
# | age(32) | 0.0153257  |
# +---------+------------+
# | age(33) | 0.00766284 |
# +---------+------------+
# | age(34) | 0.0153257  |
# +---------+------------+
# | age(35) | 0.0191571  |
# +---------+------------+
# | age(36) | 0.0191571  |
# +---------+------------+
# | age(37) | 0.0306513  |
# +---------+------------+
# | age(38) | 0.0191571  |
# +---------+------------+
# | age(39) | 0.0344828  |
# +---------+------------+
# | age(40) | 0.0191571  |
# +---------+------------+
# | age(41) | 0.0383142  |
# +---------+------------+
# | age(42) | 0.0268199  |
# +---------+------------+
# | age(43) | 0.0421456  |
# +---------+------------+
# | age(44) | 0.0268199  |
# +---------+------------+
# | age(45) | 0.0229885  |
# +---------+------------+
# | age(46) | 0.045977   |
# +---------+------------+
# | age(47) | 0.0344828  |
# +---------+------------+
# | age(48) | 0.0613027  |
# +---------+------------+
# | age(49) | 0.0421456  |
# +---------+------------+
# | age(50) | 0.045977   |
# +---------+------------+
# | age(51) | 0.0344828  |
# +---------+------------+
# | age(52) | 0.0574713  |
# +---------+------------+
# | age(53) | 0.0383142  |
# +---------+------------+
# | age(54) | 0.0842912  |
# +---------+------------+
# | age(55) | 0.0536398  |
# +---------+------------+
# | age(56) | 0.0306513  |
# +---------+------------+
# | age(57) | 0.0191571  |
# +---------+------------+
# | age(58) | 0.0344828  |
# +---------+------------+
# | age(59) | 0.0229885  |
# +---------+------------+
# | age(60) | 0.00766284 |
# +---------+------------+
# | age(61) | 0.00766284 |
# +---------+------------+
# | age(62) | 0.00766284 |
# +---------+------------+
# | age(63) | 0.00383142 |
# +---------+------------+
# | age(65) | 0.0114943  |
# +---------+------------+
# | age(66) | 0          |
# +---------+------------+

# %%
print(model.get_cpds("chol"))
# Out:
# +--------------+----------------------+----------------------+
# | heartdisease | heartdisease(0)      | heartdisease(1)      |
# +--------------+----------------------+----------------------+
# | chol(100)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(117)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(129)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(132)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(147)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(156)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(160)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(161)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(163)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(164)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(166)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(167)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(168)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(171)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(172)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(173)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(175)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(179)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(180)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(182)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(184)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(186)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(187)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(188)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(190)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(193)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(194)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(195)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(196)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(198)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(200)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(201)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(202)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(204)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(205)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(206)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(207)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(208)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(209)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(210)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(211)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(212)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(213)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(214)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(215)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(216)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(217)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(218)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(219)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(220)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(221)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(222)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(223)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(224)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(225)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(226)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(227)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(228)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(229)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(230)    | 0.024539877300613498 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(231)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(233)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(234)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(237)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(238)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(240)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(241)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(242)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(243)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(245)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(246)    | 0.012269938650306749 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(247)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(248)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(249)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(250)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(251)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(253)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(254)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(255)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(256)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(257)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(259)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(260)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(263)    | 0.006134969325153374 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(264)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(265)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(266)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(267)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(268)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(269)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(270)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(271)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(272)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(273)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(274)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(275)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(276)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(277)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(279)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(280)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(281)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(282)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(283)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(284)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(285)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(287)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(288)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(289)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(290)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(291)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(292)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(294)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(295)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(297)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(298)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(303)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(305)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(306)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(307)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(308)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(309)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(312)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(315)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(318)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(320)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(326)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(328)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(329)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(331)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(336)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(338)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(339)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(340)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(341)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(342)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(344)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(347)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(355)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(358)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(365)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(388)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(392)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(393)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(394)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(404)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(412)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(466)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(468)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(491)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(518)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(529)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(603)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(85)     | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+

# %%
print(model.get_cpds("sex"))
# Out:
# +--------+----------+
# | sex(0) | 0.264368 |
# +--------+----------+
# | sex(1) | 0.735632 |
# +--------+----------+

# %%
model.get_independencies()
# Out:
# (age _|_ sex, exang)
# (age _|_ exang | sex)
# (age _|_ chol, thalach, restecg | heartdisease)
# (age _|_ sex | exang)
# (age _|_ sex, exang | fbs)
# (age _|_ chol, thalach, restecg | heartdisease, sex)
# (age _|_ exang | fbs, sex)
# (age _|_ chol, thalach | heartdisease, restecg)
# (age _|_ chol, thalach, restecg | heartdisease, exang)
# (age _|_ chol, thalach, restecg | heartdisease, fbs)
# (age _|_ chol, thalach, restecg | heartdisease, trestbps)
# (age _|_ thalach, restecg | heartdisease, chol)
# (age _|_ chol, restecg | heartdisease, thalach)
# (age _|_ sex | fbs, exang)
# (age _|_ heartdisease, thalach, restecg, chol | fbs, trestbps)
# (age _|_ chol, thalach | heartdisease, sex, restecg)
# (age _|_ chol, thalach, restecg | heartdisease, sex, exang)
# (age _|_ chol, thalach, restecg | heartdisease, sex, fbs)
# (age _|_ chol, thalach, restecg | heartdisease, trestbps, sex)
# (age _|_ thalach, restecg | heartdisease, sex, chol)
# (age _|_ chol, restecg | heartdisease, thalach, sex)
# (age _|_ heartdisease, thalach, restecg, chol | fbs, trestbps, sex)
# (age _|_ chol, thalach | heartdisease, restecg, exang)
# (age _|_ chol, thalach | heartdisease, restecg, fbs)
# (age _|_ chol, thalach | heartdisease, trestbps, restecg)
# (age _|_ thalach | heartdisease, restecg, chol)
# (age _|_ chol | heartdisease, thalach, restecg)
# (age _|_ chol, thalach, restecg | heartdisease, exang, fbs)
# (age _|_ chol, thalach, restecg | heartdisease, trestbps, exang)
# (age _|_ thalach, restecg | heartdisease, chol, exang)
# (age _|_ chol, restecg | heartdisease, thalach, exang)
# (age _|_ chol, thalach, restecg | heartdisease, trestbps, fbs)
# (age _|_ thalach, restecg | heartdisease, chol, fbs)
# (age _|_ chol, restecg | heartdisease, thalach, fbs)
# (age _|_ thalach, restecg | heartdisease, trestbps, chol)
# (age _|_ chol, restecg | heartdisease, trestbps, thalach)
# (age _|_ restecg | heartdisease, thalach, chol)
# (age _|_ heartdisease, thalach, chol | fbs, trestbps, restecg)
# (age _|_ heartdisease, thalach, restecg, chol | fbs, trestbps, exang)
# (age _|_ heartdisease, thalach, restecg | fbs, trestbps, chol)
# (age _|_ heartdisease, restecg, chol | fbs, trestbps, thalach)
# (age _|_ chol, thalach | heartdisease, sex, exang, restecg)
# (age _|_ chol, thalach | heartdisease, sex, fbs, restecg)
# (age _|_ chol, thalach | heartdisease, trestbps, sex, restecg)
# (age _|_ thalach | heartdisease, sex, chol, restecg)
# (age _|_ chol | heartdisease, thalach, sex, restecg)
# (age _|_ chol, thalach, restecg | heartdisease, sex, exang, fbs)
# (age _|_ chol, thalach, restecg | heartdisease, trestbps, sex, exang)
# (age _|_ thalach, restecg | heartdisease, chol, sex, exang)
# (age _|_ chol, restecg | heartdisease, thalach, sex, exang)
# (age _|_ chol, thalach, restecg | heartdisease, trestbps, sex, fbs)
# (age _|_ thalach, restecg | heartdisease, chol, sex, fbs)
# (age _|_ chol, restecg | heartdisease, thalach, sex, fbs)
# (age _|_ thalach, restecg | heartdisease, trestbps, sex, chol)
# (age _|_ chol, restecg | heartdisease, trestbps, thalach, sex)
# (age _|_ restecg | heartdisease, thalach, sex, chol)
# (age _|_ heartdisease, thalach, chol | fbs, trestbps, sex, restecg)
# (age _|_ heartdisease, thalach, chol, restecg | fbs, trestbps, sex, exang)
# (age _|_ heartdisease, thalach, restecg | fbs, trestbps, sex, chol)
# (age _|_ heartdisease, restecg, chol | fbs, trestbps, thalach, sex)
# (age _|_ chol, thalach | heartdisease, restecg, exang, fbs)
# (age _|_ chol, thalach | heartdisease, trestbps, restecg, exang)
# (age _|_ thalach | heartdisease, chol, restecg, exang)
# (age _|_ chol | heartdisease, thalach, restecg, exang)
# (age _|_ chol, thalach | heartdisease, trestbps, restecg, fbs)
# (age _|_ thalach | heartdisease, chol, restecg, fbs)
# (age _|_ chol | heartdisease, thalach, restecg, fbs)
# (age _|_ thalach | heartdisease, trestbps, restecg, chol)
# (age _|_ chol | heartdisease, trestbps, thalach, restecg)
# (age _|_ chol, thalach, restecg | heartdisease, trestbps, exang, fbs)
# (age _|_ thalach, restecg | heartdisease, chol, exang, fbs)
# (age _|_ chol, restecg | heartdisease, thalach, exang, fbs)
# (age _|_ thalach, restecg | heartdisease, trestbps, chol, exang)
# (age _|_ chol, restecg | heartdisease, trestbps, thalach, exang)
# (age _|_ restecg | heartdisease, chol, thalach, exang)
# (age _|_ thalach, restecg | heartdisease, trestbps, chol, fbs)
# (age _|_ chol, restecg | heartdisease, trestbps, thalach, fbs)
# (age _|_ restecg | heartdisease, chol, thalach, fbs)
# (age _|_ restecg | heartdisease, trestbps, thalach, chol)
# (age _|_ heartdisease, thalach, chol | fbs, trestbps, restecg, exang)
# (age _|_ heartdisease, thalach | fbs, trestbps, restecg, chol)
# (age _|_ heartdisease, chol | fbs, trestbps, thalach, restecg)
# (age _|_ heartdisease, thalach, restecg | fbs, trestbps, chol, exang)
# (age _|_ heartdisease, restecg, chol | fbs, trestbps, thalach, exang)
# (age _|_ heartdisease, restecg | fbs, trestbps, thalach, chol)
# (age _|_ chol, thalach | sex, heartdisease, restecg, exang, fbs)
# (age _|_ chol, thalach | sex, heartdisease, restecg, exang, trestbps)
# (age _|_ thalach | sex, heartdisease, restecg, exang, chol)
# (age _|_ chol | sex, heartdisease, restecg, exang, thalach)
# (age _|_ chol, thalach | sex, heartdisease, restecg, fbs, trestbps)
# (age _|_ thalach | sex, heartdisease, restecg, fbs, chol)
# (age _|_ chol | sex, heartdisease, restecg, fbs, thalach)
# (age _|_ thalach | sex, heartdisease, restecg, trestbps, chol)
# (age _|_ chol | sex, heartdisease, restecg, trestbps, thalach)
# (age _|_ chol, thalach, restecg | sex, heartdisease, exang, fbs, trestbps)
# (age _|_ thalach, restecg | sex, heartdisease, exang, fbs, chol)
# (age _|_ chol, restecg | sex, heartdisease, exang, fbs, thalach)
# (age _|_ thalach, restecg | sex, heartdisease, exang, trestbps, chol)
# (age _|_ chol, restecg | sex, heartdisease, exang, trestbps, thalach)
# (age _|_ restecg | sex, heartdisease, exang, chol, thalach)
# (age _|_ thalach, restecg | sex, heartdisease, fbs, trestbps, chol)
# (age _|_ chol, restecg | sex, heartdisease, fbs, trestbps, thalach)
# (age _|_ restecg | sex, heartdisease, fbs, chol, thalach)
# (age _|_ restecg | sex, heartdisease, trestbps, chol, thalach)
# (age _|_ heartdisease, thalach, chol | sex, restecg, exang, fbs, trestbps)
# (age _|_ heartdisease, thalach | sex, restecg, fbs, trestbps, chol)
# (age _|_ heartdisease, chol | sex, restecg, fbs, trestbps, thalach)
# (age _|_ heartdisease, thalach, restecg | sex, exang, fbs, trestbps, chol)
# (age _|_ heartdisease, restecg, chol | sex, exang, fbs, trestbps, thalach)
# (age _|_ heartdisease, restecg | sex, fbs, trestbps, chol, thalach)
# (age _|_ chol, thalach | heartdisease, restecg, exang, fbs, trestbps)
# (age _|_ thalach | heartdisease, restecg, exang, fbs, chol)
# (age _|_ chol | heartdisease, restecg, exang, fbs, thalach)
# (age _|_ thalach | heartdisease, restecg, exang, trestbps, chol)
# (age _|_ chol | heartdisease, restecg, exang, trestbps, thalach)
# (age _|_ thalach | heartdisease, restecg, fbs, trestbps, chol)
# (age _|_ chol | heartdisease, restecg, fbs, trestbps, thalach)
# (age _|_ thalach, restecg | heartdisease, exang, fbs, trestbps, chol)
# (age _|_ chol, restecg | heartdisease, exang, fbs, trestbps, thalach)
# (age _|_ restecg | heartdisease, exang, fbs, chol, thalach)
# (age _|_ restecg | heartdisease, exang, trestbps, chol, thalach)
# (age _|_ restecg | heartdisease, fbs, trestbps, chol, thalach)
# (age _|_ heartdisease, thalach | restecg, exang, fbs, trestbps, chol)
# (age _|_ heartdisease, chol | restecg, exang, fbs, trestbps, thalach)
# (age _|_ heartdisease | restecg, fbs, trestbps, chol, thalach)
# (age _|_ heartdisease, restecg | exang, fbs, trestbps, chol, thalach)
# (age _|_ chol, thalach | sex, heartdisease, restecg, exang, fbs, trestbps)
# (age _|_ thalach | sex, heartdisease, restecg, exang, fbs, chol)
# (age _|_ chol | sex, heartdisease, restecg, exang, fbs, thalach)
# (age _|_ thalach | sex, heartdisease, restecg, exang, trestbps, chol)
# (age _|_ chol | sex, heartdisease, restecg, exang, trestbps, thalach)
# (age _|_ thalach | sex, heartdisease, restecg, fbs, trestbps, chol)
# (age _|_ chol | sex, heartdisease, restecg, fbs, trestbps, thalach)
# (age _|_ thalach, restecg | sex, heartdisease, exang, fbs, trestbps, chol)
# (age _|_ chol, restecg | sex, heartdisease, exang, fbs, trestbps, thalach)
# (age _|_ restecg | sex, heartdisease, exang, fbs, chol, thalach)
# (age _|_ restecg | sex, heartdisease, exang, trestbps, chol, thalach)
# (age _|_ restecg | sex, heartdisease, fbs, trestbps, chol, thalach)
# (age _|_ heartdisease, thalach | sex, restecg, exang, fbs, trestbps, chol)
# (age _|_ heartdisease, chol | sex, restecg, exang, fbs, trestbps, thalach)
# (age _|_ heartdisease | sex, restecg, fbs, trestbps, chol, thalach)
# (age _|_ heartdisease, restecg | sex, exang, fbs, trestbps, chol, thalach)
# (age _|_ thalach | heartdisease, restecg, exang, fbs, trestbps, chol)
# (age _|_ chol | heartdisease, restecg, exang, fbs, trestbps, thalach)
# (age _|_ restecg | heartdisease, exang, fbs, trestbps, chol, thalach)
# (age _|_ heartdisease | restecg, exang, fbs, trestbps, chol, thalach)
# (age _|_ thalach | sex, heartdisease, restecg, exang, fbs, trestbps, chol)
# (age _|_ chol | sex, heartdisease, restecg, exang, fbs, trestbps, thalach)
# (age _|_ restecg | sex, heartdisease, exang, fbs, trestbps, chol, thalach)
# (age _|_ heartdisease | sex, restecg, exang, fbs, trestbps, chol, thalach)
# (trestbps _|_ chol, thalach, restecg | heartdisease)
# (trestbps _|_ fbs | age)
# (trestbps _|_ chol, thalach, restecg | heartdisease, sex)
# (trestbps _|_ fbs | age, sex)
# (trestbps _|_ chol, thalach | heartdisease, restecg)
# (trestbps _|_ chol, thalach, restecg | heartdisease, exang)
# (trestbps _|_ chol, thalach, restecg | heartdisease, fbs)
# (trestbps _|_ thalach, restecg | heartdisease, chol)
# (trestbps _|_ chol, thalach, restecg | heartdisease, age)
# (trestbps _|_ chol, restecg | heartdisease, thalach)
# (trestbps _|_ fbs | age, exang)
# (trestbps _|_ chol, thalach | heartdisease, sex, restecg)
# (trestbps _|_ chol, thalach, restecg | heartdisease, sex, exang)
# (trestbps _|_ chol, thalach, restecg | heartdisease, sex, fbs)
# (trestbps _|_ thalach, restecg | heartdisease, sex, chol)
# (trestbps _|_ chol, thalach, restecg | heartdisease, age, sex)
# (trestbps _|_ chol, restecg | heartdisease, thalach, sex)
# (trestbps _|_ fbs | age, sex, exang)
# (trestbps _|_ chol, thalach | heartdisease, restecg, exang)
# (trestbps _|_ chol, thalach | heartdisease, restecg, fbs)
# (trestbps _|_ thalach | heartdisease, restecg, chol)
# (trestbps _|_ chol, thalach | heartdisease, age, restecg)
# (trestbps _|_ chol | heartdisease, thalach, restecg)
# (trestbps _|_ chol, thalach, restecg | heartdisease, exang, fbs)
# (trestbps _|_ thalach, restecg | heartdisease, chol, exang)
# (trestbps _|_ chol, thalach, restecg | heartdisease, age, exang)
# (trestbps _|_ chol, restecg | heartdisease, thalach, exang)
# (trestbps _|_ thalach, restecg | heartdisease, chol, fbs)
# (trestbps _|_ chol, thalach, restecg | heartdisease, age, fbs)
# (trestbps _|_ chol, restecg | heartdisease, thalach, fbs)
# (trestbps _|_ thalach, restecg | heartdisease, age, chol)
# (trestbps _|_ restecg | heartdisease, thalach, chol)
# (trestbps _|_ chol, restecg | heartdisease, age, thalach)
# (trestbps _|_ chol, thalach | heartdisease, sex, exang, restecg)
# (trestbps _|_ chol, thalach | heartdisease, sex, fbs, restecg)
# (trestbps _|_ thalach | heartdisease, sex, chol, restecg)
# (trestbps _|_ chol, thalach | heartdisease, age, sex, restecg)
# (trestbps _|_ chol | heartdisease, thalach, sex, restecg)
# (trestbps _|_ chol, thalach, restecg | heartdisease, sex, exang, fbs)
# (trestbps _|_ thalach, restecg | heartdisease, chol, sex, exang)
# (trestbps _|_ chol, thalach, restecg | heartdisease, age, sex, exang)
# (trestbps _|_ chol, restecg | heartdisease, thalach, sex, exang)
# (trestbps _|_ thalach, restecg | heartdisease, chol, sex, fbs)
# (trestbps _|_ chol, thalach, restecg | heartdisease, age, sex, fbs)
# (trestbps _|_ chol, restecg | heartdisease, thalach, sex, fbs)
# (trestbps _|_ thalach, restecg | heartdisease, age, sex, chol)
# (trestbps _|_ restecg | heartdisease, thalach, sex, chol)
# (trestbps _|_ chol, restecg | heartdisease, age, thalach, sex)
# (trestbps _|_ chol, thalach | heartdisease, restecg, exang, fbs)
# (trestbps _|_ thalach | heartdisease, chol, restecg, exang)
# (trestbps _|_ chol, thalach | heartdisease, age, restecg, exang)
# (trestbps _|_ chol | heartdisease, thalach, restecg, exang)
# (trestbps _|_ thalach | heartdisease, chol, restecg, fbs)
# (trestbps _|_ chol, thalach | heartdisease, age, restecg, fbs)
# (trestbps _|_ chol | heartdisease, thalach, restecg, fbs)
# (trestbps _|_ thalach | heartdisease, age, restecg, chol)
# (trestbps _|_ chol | heartdisease, age, thalach, restecg)
# (trestbps _|_ thalach, restecg | heartdisease, chol, exang, fbs)
# (trestbps _|_ chol, thalach, restecg | heartdisease, age, exang, fbs)
# (trestbps _|_ chol, restecg | heartdisease, thalach, exang, fbs)
# (trestbps _|_ thalach, restecg | heartdisease, age, chol, exang)
# (trestbps _|_ restecg | heartdisease, chol, thalach, exang)
# (trestbps _|_ chol, restecg | heartdisease, age, thalach, exang)
# (trestbps _|_ thalach, restecg | heartdisease, age, chol, fbs)
# (trestbps _|_ restecg | heartdisease, chol, thalach, fbs)
# (trestbps _|_ chol, restecg | heartdisease, age, thalach, fbs)
# (trestbps _|_ restecg | heartdisease, age, thalach, chol)
# (trestbps _|_ chol, thalach | sex, heartdisease, restecg, exang, fbs)
# (trestbps _|_ thalach | sex, heartdisease, restecg, exang, chol)
# (trestbps _|_ chol, thalach | sex, heartdisease, restecg, exang, age)
# (trestbps _|_ chol | sex, heartdisease, restecg, exang, thalach)
# (trestbps _|_ thalach | sex, heartdisease, restecg, fbs, chol)
# (trestbps _|_ chol, thalach | sex, heartdisease, restecg, fbs, age)
# (trestbps _|_ chol | sex, heartdisease, restecg, fbs, thalach)
# (trestbps _|_ thalach | sex, heartdisease, restecg, chol, age)
# (trestbps _|_ chol | sex, heartdisease, restecg, age, thalach)
# (trestbps _|_ thalach, restecg | sex, heartdisease, exang, fbs, chol)
# (trestbps _|_ chol, thalach, restecg | sex, heartdisease, exang, fbs, age)
# (trestbps _|_ chol, restecg | sex, heartdisease, exang, fbs, thalach)
# (trestbps _|_ thalach, restecg | sex, heartdisease, exang, chol, age)
# (trestbps _|_ restecg | sex, heartdisease, exang, chol, thalach)
# (trestbps _|_ chol, restecg | sex, heartdisease, exang, age, thalach)
# (trestbps _|_ thalach, restecg | sex, heartdisease, fbs, chol, age)
# (trestbps _|_ restecg | sex, heartdisease, fbs, chol, thalach)
# (trestbps _|_ chol, restecg | sex, heartdisease, fbs, age, thalach)
# (trestbps _|_ restecg | sex, heartdisease, chol, age, thalach)
# (trestbps _|_ thalach | heartdisease, restecg, exang, fbs, chol)
# (trestbps _|_ chol, thalach | heartdisease, restecg, exang, fbs, age)
# (trestbps _|_ chol | heartdisease, restecg, exang, fbs, thalach)
# (trestbps _|_ thalach | heartdisease, restecg, exang, chol, age)
# (trestbps _|_ chol | heartdisease, restecg, exang, age, thalach)
# (trestbps _|_ thalach | heartdisease, restecg, fbs, chol, age)
# (trestbps _|_ chol | heartdisease, restecg, fbs, age, thalach)
# (trestbps _|_ thalach, restecg | heartdisease, exang, fbs, chol, age)
# (trestbps _|_ restecg | heartdisease, exang, fbs, chol, thalach)
# (trestbps _|_ chol, restecg | heartdisease, exang, fbs, age, thalach)
# (trestbps _|_ restecg | heartdisease, exang, chol, age, thalach)
# (trestbps _|_ restecg | heartdisease, fbs, chol, age, thalach)
# (trestbps _|_ thalach | sex, heartdisease, restecg, exang, fbs, chol)
# (trestbps _|_ chol, thalach | sex, heartdisease, restecg, exang, fbs, age)
# (trestbps _|_ chol | sex, heartdisease, restecg, exang, fbs, thalach)
# (trestbps _|_ thalach | sex, heartdisease, restecg, exang, chol, age)
# (trestbps _|_ chol | sex, heartdisease, restecg, exang, age, thalach)
# (trestbps _|_ thalach | sex, heartdisease, restecg, fbs, chol, age)
# (trestbps _|_ chol | sex, heartdisease, restecg, fbs, age, thalach)
# (trestbps _|_ thalach, restecg | sex, heartdisease, exang, fbs, chol, age)
# (trestbps _|_ restecg | sex, heartdisease, exang, fbs, chol, thalach)
# (trestbps _|_ chol, restecg | sex, heartdisease, exang, fbs, age, thalach)
# (trestbps _|_ restecg | sex, heartdisease, exang, chol, age, thalach)
# (trestbps _|_ restecg | sex, heartdisease, fbs, chol, age, thalach)
# (trestbps _|_ thalach | heartdisease, restecg, exang, fbs, chol, age)
# (trestbps _|_ chol | heartdisease, restecg, exang, fbs, age, thalach)
# (trestbps _|_ restecg | heartdisease, exang, fbs, chol, age, thalach)
# (trestbps _|_ thalach | sex, heartdisease, restecg, exang, fbs, chol, age)
# (trestbps _|_ chol | sex, heartdisease, restecg, exang, fbs, age, thalach)
# (trestbps _|_ restecg | sex, heartdisease, exang, fbs, chol, age, thalach)
# (fbs _|_ sex, exang)
# (fbs _|_ exang | sex)
# (fbs _|_ chol, thalach, restecg | heartdisease)
# (fbs _|_ sex | exang)
# (fbs _|_ trestbps, sex, exang | age)
# (fbs _|_ chol, thalach, restecg | heartdisease, sex)
# (fbs _|_ trestbps, exang | age, sex)
# (fbs _|_ chol, thalach | heartdisease, restecg)
# (fbs _|_ chol, thalach, restecg | heartdisease, exang)
# (fbs _|_ chol, thalach, restecg | heartdisease, trestbps)
# (fbs _|_ thalach, restecg | heartdisease, chol)
# (fbs _|_ chol, thalach, restecg | heartdisease, age)
# (fbs _|_ chol, restecg | heartdisease, thalach)
# (fbs _|_ trestbps, sex | age, exang)
# (fbs _|_ sex, exang | age, trestbps)
# (fbs _|_ chol, thalach | heartdisease, sex, restecg)
# (fbs _|_ chol, thalach, restecg | heartdisease, sex, exang)
# (fbs _|_ chol, thalach, restecg | heartdisease, trestbps, sex)
# (fbs _|_ thalach, restecg | heartdisease, sex, chol)
# (fbs _|_ chol, thalach, restecg | heartdisease, age, sex)
# (fbs _|_ chol, restecg | heartdisease, thalach, sex)
# (fbs _|_ trestbps | age, sex, exang)
# (fbs _|_ exang | age, trestbps, sex)
# (fbs _|_ chol, thalach | heartdisease, restecg, exang)
# (fbs _|_ chol, thalach | heartdisease, trestbps, restecg)
# (fbs _|_ thalach | heartdisease, restecg, chol)
# (fbs _|_ chol, thalach | heartdisease, age, restecg)
# (fbs _|_ chol | heartdisease, thalach, restecg)
# (fbs _|_ chol, thalach, restecg | heartdisease, trestbps, exang)
# (fbs _|_ thalach, restecg | heartdisease, chol, exang)
# (fbs _|_ chol, thalach, restecg | heartdisease, age, exang)
# (fbs _|_ chol, restecg | heartdisease, thalach, exang)
# (fbs _|_ thalach, restecg | heartdisease, trestbps, chol)
# (fbs _|_ sex, chol, thalach, restecg, exang | heartdisease, age, trestbps)
# (fbs _|_ chol, restecg | heartdisease, trestbps, thalach)
# (fbs _|_ thalach, restecg | heartdisease, age, chol)
# (fbs _|_ restecg | heartdisease, thalach, chol)
# (fbs _|_ chol, restecg | heartdisease, age, thalach)
# (fbs _|_ sex, exang | age, trestbps, restecg)
# (fbs _|_ sex | age, trestbps, exang)
# (fbs _|_ sex, exang | chol, age, trestbps)
# (fbs _|_ sex, exang | age, trestbps, thalach)
# (fbs _|_ chol, thalach | heartdisease, sex, exang, restecg)
# (fbs _|_ chol, thalach | heartdisease, trestbps, sex, restecg)
# (fbs _|_ thalach | heartdisease, sex, chol, restecg)
# (fbs _|_ chol, thalach | heartdisease, age, sex, restecg)
# (fbs _|_ chol | heartdisease, thalach, sex, restecg)
# (fbs _|_ chol, thalach, restecg | heartdisease, trestbps, sex, exang)
# (fbs _|_ thalach, restecg | heartdisease, chol, sex, exang)
# (fbs _|_ chol, thalach, restecg | heartdisease, age, sex, exang)
# (fbs _|_ chol, restecg | heartdisease, thalach, sex, exang)
# (fbs _|_ thalach, restecg | heartdisease, trestbps, sex, chol)
# (fbs _|_ chol, thalach, exang, restecg | heartdisease, age, trestbps, sex)
# (fbs _|_ chol, restecg | heartdisease, trestbps, thalach, sex)
# (fbs _|_ thalach, restecg | heartdisease, age, sex, chol)
# (fbs _|_ restecg | heartdisease, thalach, sex, chol)
# (fbs _|_ chol, restecg | heartdisease, age, thalach, sex)
# (fbs _|_ exang | age, trestbps, sex, restecg)
# (fbs _|_ exang | chol, age, trestbps, sex)
# (fbs _|_ exang | age, trestbps, thalach, sex)
# (fbs _|_ chol, thalach | heartdisease, trestbps, restecg, exang)
# (fbs _|_ thalach | heartdisease, chol, restecg, exang)
# (fbs _|_ chol, thalach | heartdisease, age, restecg, exang)
# (fbs _|_ chol | heartdisease, thalach, restecg, exang)
# (fbs _|_ thalach | heartdisease, trestbps, restecg, chol)
# (fbs _|_ chol, sex, thalach, exang | heartdisease, age, trestbps, restecg)
# (fbs _|_ chol | heartdisease, trestbps, thalach, restecg)
# (fbs _|_ thalach | heartdisease, age, restecg, chol)
# (fbs _|_ chol | heartdisease, age, thalach, restecg)
# (fbs _|_ thalach, restecg | heartdisease, trestbps, chol, exang)
# (fbs _|_ chol, sex, thalach, restecg | heartdisease, age, trestbps, exang)
# (fbs _|_ chol, restecg | heartdisease, trestbps, thalach, exang)
# (fbs _|_ thalach, restecg | heartdisease, age, chol, exang)
# (fbs _|_ restecg | heartdisease, chol, thalach, exang)
# (fbs _|_ chol, restecg | heartdisease, age, thalach, exang)
# (fbs _|_ sex, thalach, exang, restecg | heartdisease, age, trestbps, chol)
# (fbs _|_ restecg | heartdisease, trestbps, thalach, chol)
# (fbs _|_ chol, sex, exang, restecg | heartdisease, age, trestbps, thalach)
# (fbs _|_ restecg | heartdisease, age, thalach, chol)
# (fbs _|_ sex | age, trestbps, restecg, exang)
# (fbs _|_ sex, exang | chol, age, trestbps, restecg)
# (fbs _|_ sex, exang | age, trestbps, thalach, restecg)
# (fbs _|_ sex | chol, age, trestbps, exang)
# (fbs _|_ sex | age, trestbps, thalach, exang)
# (fbs _|_ sex, exang | chol, age, trestbps, thalach)
# (fbs _|_ chol, thalach | sex, heartdisease, restecg, exang, trestbps)
# (fbs _|_ thalach | sex, heartdisease, restecg, exang, chol)
# (fbs _|_ chol, thalach | sex, heartdisease, restecg, exang, age)
# (fbs _|_ chol | sex, heartdisease, restecg, exang, thalach)
# (fbs _|_ thalach | sex, heartdisease, restecg, trestbps, chol)
# (fbs _|_ chol, thalach, exang | sex, heartdisease, restecg, trestbps, age)
# (fbs _|_ chol | sex, heartdisease, restecg, trestbps, thalach)
# (fbs _|_ thalach | sex, heartdisease, restecg, chol, age)
# (fbs _|_ chol | sex, heartdisease, restecg, age, thalach)
# (fbs _|_ thalach, restecg | sex, heartdisease, exang, trestbps, chol)
# (fbs _|_ chol, thalach, restecg | sex, heartdisease, exang, trestbps, age)
# (fbs _|_ chol, restecg | sex, heartdisease, exang, trestbps, thalach)
# (fbs _|_ thalach, restecg | sex, heartdisease, exang, chol, age)
# (fbs _|_ restecg | sex, heartdisease, exang, chol, thalach)
# (fbs _|_ chol, restecg | sex, heartdisease, exang, age, thalach)
# (fbs _|_ thalach, exang, restecg | sex, heartdisease, trestbps, chol, age)
# (fbs _|_ restecg | sex, heartdisease, trestbps, chol, thalach)
# (fbs _|_ chol, restecg, exang | sex, heartdisease, trestbps, age, thalach)
# (fbs _|_ restecg | sex, heartdisease, chol, age, thalach)
# (fbs _|_ exang | sex, restecg, trestbps, chol, age)
# (fbs _|_ exang | sex, restecg, trestbps, age, thalach)
# (fbs _|_ exang | sex, trestbps, chol, age, thalach)
# (fbs _|_ thalach | heartdisease, restecg, exang, trestbps, chol)
# (fbs _|_ chol, sex, thalach | heartdisease, restecg, exang, trestbps, age)
# (fbs _|_ chol | heartdisease, restecg, exang, trestbps, thalach)
# (fbs _|_ thalach | heartdisease, restecg, exang, chol, age)
# (fbs _|_ chol | heartdisease, restecg, exang, age, thalach)
# (fbs _|_ sex, thalach, exang | heartdisease, restecg, trestbps, chol, age)
# (fbs _|_ chol, sex, exang | heartdisease, restecg, trestbps, age, thalach)
# (fbs _|_ sex, thalach, restecg | heartdisease, exang, trestbps, chol, age)
# (fbs _|_ restecg | heartdisease, exang, trestbps, chol, thalach)
# (fbs _|_ chol, sex, restecg | heartdisease, exang, trestbps, age, thalach)
# (fbs _|_ restecg | heartdisease, exang, chol, age, thalach)
# (fbs _|_ sex, exang, restecg | heartdisease, trestbps, chol, age, thalach)
# (fbs _|_ sex | restecg, exang, trestbps, chol, age)
# (fbs _|_ sex | restecg, exang, trestbps, age, thalach)
# (fbs _|_ sex, exang | restecg, trestbps, chol, age, thalach)
# (fbs _|_ sex | exang, trestbps, chol, age, thalach)
# (fbs _|_ thalach | sex, heartdisease, restecg, exang, trestbps, chol)
# (fbs _|_ chol, thalach | sex, heartdisease, restecg, exang, trestbps, age)
# (fbs _|_ chol | sex, heartdisease, restecg, exang, trestbps, thalach)
# (fbs _|_ thalach | sex, heartdisease, restecg, exang, chol, age)
# (fbs _|_ chol | sex, heartdisease, restecg, exang, age, thalach)
# (fbs _|_ thalach, exang | sex, heartdisease, restecg, trestbps, chol, age)
# (fbs _|_ chol, exang | sex, heartdisease, restecg, trestbps, age, thalach)
# (fbs _|_ thalach, restecg | sex, heartdisease, exang, trestbps, chol, age)
# (fbs _|_ restecg | sex, heartdisease, exang, trestbps, chol, thalach)
# (fbs _|_ chol, restecg | sex, heartdisease, exang, trestbps, age, thalach)
# (fbs _|_ restecg | sex, heartdisease, exang, chol, age, thalach)
# (fbs _|_ restecg, exang | sex, heartdisease, trestbps, chol, age, thalach)
# (fbs _|_ exang | sex, restecg, trestbps, chol, age, thalach)
# (fbs _|_ sex, thalach | heartdisease, restecg, exang, trestbps, chol, age)
# (fbs _|_ chol, sex | heartdisease, restecg, exang, trestbps, age, thalach)
# (fbs _|_ sex, exang | heartdisease, restecg, trestbps, chol, age, thalach)
# (fbs _|_ sex, restecg | heartdisease, exang, trestbps, chol, age, thalach)
# (fbs _|_ sex | restecg, exang, trestbps, chol, age, thalach)
# (fbs _|_ thalach | sex, heartdisease, restecg, exang, trestbps, chol, age)
# (fbs _|_ chol | sex, heartdisease, restecg, exang, trestbps, age, thalach)
# (fbs _|_ exang | sex, heartdisease, restecg, trestbps, chol, age, thalach)
# (fbs _|_ restecg | sex, heartdisease, exang, trestbps, chol, age, thalach)
# (fbs _|_ sex | heartdisease, restecg, exang, trestbps, chol, age, thalach)
# (sex _|_ fbs, age, exang)
# (sex _|_ chol, thalach, restecg | heartdisease)
# (sex _|_ fbs, age | exang)
# (sex _|_ age, exang | fbs)
# (sex _|_ fbs, exang | age)
# (sex _|_ chol, thalach | heartdisease, restecg)
# (sex _|_ chol, thalach, restecg | heartdisease, exang)
# (sex _|_ chol, thalach, restecg | heartdisease, fbs)
# (sex _|_ chol, thalach, restecg | heartdisease, trestbps)
# (sex _|_ thalach, restecg | heartdisease, chol)
# (sex _|_ chol, thalach, restecg | heartdisease, age)
# (sex _|_ chol, restecg | heartdisease, thalach)
# (sex _|_ age | fbs, exang)
# (sex _|_ fbs | age, exang)
# (sex _|_ heartdisease, thalach, restecg, chol | fbs, trestbps)
# (sex _|_ exang | fbs, age)
# (sex _|_ fbs, heartdisease, thalach, restecg, chol | age, trestbps)
# (sex _|_ chol, thalach | heartdisease, restecg, exang)
# (sex _|_ chol, thalach | heartdisease, restecg, fbs)
# (sex _|_ chol, thalach | heartdisease, trestbps, restecg)
# (sex _|_ thalach | heartdisease, restecg, chol)
# (sex _|_ chol, thalach | heartdisease, age, restecg)
# (sex _|_ chol | heartdisease, thalach, restecg)
# (sex _|_ chol, thalach, restecg | heartdisease, exang, fbs)
# (sex _|_ chol, thalach, restecg | heartdisease, trestbps, exang)
# (sex _|_ thalach, restecg | heartdisease, chol, exang)
# (sex _|_ chol, thalach, restecg | heartdisease, age, exang)
# (sex _|_ chol, restecg | heartdisease, thalach, exang)
# (sex _|_ chol, thalach, restecg | heartdisease, trestbps, fbs)
# (sex _|_ thalach, restecg | heartdisease, chol, fbs)
# (sex _|_ chol, thalach, restecg | heartdisease, age, fbs)
# (sex _|_ chol, restecg | heartdisease, thalach, fbs)
# (sex _|_ thalach, restecg | heartdisease, trestbps, chol)
# (sex _|_ fbs, thalach, restecg, chol | heartdisease, age, trestbps)
# (sex _|_ chol, restecg | heartdisease, trestbps, thalach)
# (sex _|_ thalach, restecg | heartdisease, age, chol)
# (sex _|_ restecg | heartdisease, thalach, chol)
# (sex _|_ chol, restecg | heartdisease, age, thalach)
# (sex _|_ heartdisease, thalach, chol | fbs, trestbps, restecg)
# (sex _|_ heartdisease, chol, thalach, fbs | age, trestbps, restecg)
# (sex _|_ heartdisease, thalach, restecg, chol | fbs, trestbps, exang)
# (sex _|_ fbs, heartdisease, thalach, restecg, chol | age, trestbps, exang)
# (sex _|_ heartdisease, thalach, restecg | fbs, trestbps, chol)
# (sex _|_ heartdisease, thalach, restecg, chol | fbs, age, trestbps)
# (sex _|_ heartdisease, restecg, chol | fbs, trestbps, thalach)
# (sex _|_ heartdisease, thalach, restecg, fbs | chol, age, trestbps)
# (sex _|_ heartdisease, chol, restecg, fbs | age, trestbps, thalach)
# (sex _|_ chol, thalach | heartdisease, restecg, exang, fbs)
# (sex _|_ chol, thalach | heartdisease, trestbps, restecg, exang)
# (sex _|_ thalach | heartdisease, chol, restecg, exang)
# (sex _|_ chol, thalach | heartdisease, age, restecg, exang)
# (sex _|_ chol | heartdisease, thalach, restecg, exang)
# (sex _|_ chol, thalach | heartdisease, trestbps, restecg, fbs)
# (sex _|_ thalach | heartdisease, chol, restecg, fbs)
# (sex _|_ chol, thalach | heartdisease, age, restecg, fbs)
# (sex _|_ chol | heartdisease, thalach, restecg, fbs)
# (sex _|_ thalach | heartdisease, trestbps, restecg, chol)
# (sex _|_ fbs, thalach, chol | heartdisease, age, trestbps, restecg)
# (sex _|_ chol | heartdisease, trestbps, thalach, restecg)
# (sex _|_ thalach | heartdisease, age, restecg, chol)
# (sex _|_ chol | heartdisease, age, thalach, restecg)
# (sex _|_ chol, thalach, restecg | heartdisease, trestbps, exang, fbs)
# (sex _|_ thalach, restecg | heartdisease, chol, exang, fbs)
# (sex _|_ chol, thalach, restecg | heartdisease, age, exang, fbs)
# (sex _|_ chol, restecg | heartdisease, thalach, exang, fbs)
# (sex _|_ thalach, restecg | heartdisease, trestbps, chol, exang)
# (sex _|_ fbs, thalach, chol, restecg | heartdisease, age, trestbps, exang)
# (sex _|_ chol, restecg | heartdisease, trestbps, thalach, exang)
# (sex _|_ thalach, restecg | heartdisease, age, chol, exang)
# (sex _|_ restecg | heartdisease, chol, thalach, exang)
# (sex _|_ chol, restecg | heartdisease, age, thalach, exang)
# (sex _|_ thalach, restecg | heartdisease, trestbps, chol, fbs)
# (sex _|_ chol, thalach, restecg | heartdisease, age, trestbps, fbs)
# (sex _|_ chol, restecg | heartdisease, trestbps, thalach, fbs)
# (sex _|_ thalach, restecg | heartdisease, age, chol, fbs)
# (sex _|_ restecg | heartdisease, chol, thalach, fbs)
# (sex _|_ chol, restecg | heartdisease, age, thalach, fbs)
# (sex _|_ fbs, thalach, restecg | heartdisease, age, trestbps, chol)
# (sex _|_ restecg | heartdisease, trestbps, thalach, chol)
# (sex _|_ fbs, restecg, chol | heartdisease, age, trestbps, thalach)
# (sex _|_ restecg | heartdisease, age, thalach, chol)
# (sex _|_ heartdisease, thalach, chol | fbs, trestbps, restecg, exang)
# (sex _|_ heartdisease, thalach, chol, fbs | age, trestbps, restecg, exang)
# (sex _|_ heartdisease, thalach | fbs, trestbps, restecg, chol)
# (sex _|_ heartdisease, thalach, chol | fbs, age, trestbps, restecg)
# (sex _|_ heartdisease, chol | fbs, trestbps, thalach, restecg)
# (sex _|_ heartdisease, thalach, fbs | chol, age, trestbps, restecg)
# (sex _|_ heartdisease, chol, fbs | age, trestbps, thalach, restecg)
# (sex _|_ heartdisease, thalach, restecg | fbs, trestbps, chol, exang)
# (sex _|_ heartdisease, thalach, chol, restecg | fbs, age, trestbps, exang)
# (sex _|_ heartdisease, restecg, chol | fbs, trestbps, thalach, exang)
# (sex _|_ heartdisease, thalach, fbs, restecg | chol, age, trestbps, exang)
# (sex _|_ heartdisease, restecg, chol, fbs | age, trestbps, thalach, exang)
# (sex _|_ heartdisease, thalach, restecg | fbs, age, trestbps, chol)
# (sex _|_ heartdisease, restecg | fbs, trestbps, thalach, chol)
# (sex _|_ heartdisease, restecg, chol | fbs, age, trestbps, thalach)
# (sex _|_ heartdisease, restecg, fbs | chol, age, trestbps, thalach)
# (sex _|_ chol, thalach | heartdisease, restecg, exang, fbs, trestbps)
# (sex _|_ thalach | heartdisease, restecg, exang, fbs, chol)
# (sex _|_ chol, thalach | heartdisease, restecg, exang, fbs, age)
# (sex _|_ chol | heartdisease, restecg, exang, fbs, thalach)
# (sex _|_ thalach | heartdisease, restecg, exang, trestbps, chol)
# (sex _|_ fbs, thalach, chol | heartdisease, restecg, exang, trestbps, age)
# (sex _|_ chol | heartdisease, restecg, exang, trestbps, thalach)
# (sex _|_ thalach | heartdisease, restecg, exang, chol, age)
# (sex _|_ chol | heartdisease, restecg, exang, age, thalach)
# (sex _|_ thalach | heartdisease, restecg, fbs, trestbps, chol)
# (sex _|_ chol, thalach | heartdisease, restecg, fbs, trestbps, age)
# (sex _|_ chol | heartdisease, restecg, fbs, trestbps, thalach)
# (sex _|_ thalach | heartdisease, restecg, fbs, chol, age)
# (sex _|_ chol | heartdisease, restecg, fbs, age, thalach)
# (sex _|_ fbs, thalach | heartdisease, restecg, trestbps, chol, age)
# (sex _|_ fbs, chol | heartdisease, restecg, trestbps, age, thalach)
# (sex _|_ thalach, restecg | heartdisease, exang, fbs, trestbps, chol)
# (sex _|_ chol, thalach, restecg | heartdisease, exang, fbs, trestbps, age)
# (sex _|_ chol, restecg | heartdisease, exang, fbs, trestbps, thalach)
# (sex _|_ thalach, restecg | heartdisease, exang, fbs, chol, age)
# (sex _|_ restecg | heartdisease, exang, fbs, chol, thalach)
# (sex _|_ chol, restecg | heartdisease, exang, fbs, age, thalach)
# (sex _|_ fbs, thalach, restecg | heartdisease, exang, trestbps, chol, age)
# (sex _|_ restecg | heartdisease, exang, trestbps, chol, thalach)
# (sex _|_ fbs, restecg, chol | heartdisease, exang, trestbps, age, thalach)
# (sex _|_ restecg | heartdisease, exang, chol, age, thalach)
# (sex _|_ thalach, restecg | heartdisease, fbs, trestbps, chol, age)
# (sex _|_ restecg | heartdisease, fbs, trestbps, chol, thalach)
# (sex _|_ chol, restecg | heartdisease, fbs, trestbps, age, thalach)
# (sex _|_ restecg | heartdisease, fbs, chol, age, thalach)
# (sex _|_ fbs, restecg | heartdisease, trestbps, chol, age, thalach)
# (sex _|_ heartdisease, thalach | restecg, exang, fbs, trestbps, chol)
# (sex _|_ heartdisease, thalach, chol | restecg, exang, fbs, trestbps, age)
# (sex _|_ heartdisease, chol | restecg, exang, fbs, trestbps, thalach)
# (sex _|_ heartdisease, thalach, fbs | restecg, exang, trestbps, chol, age)
# (sex _|_ heartdisease, chol, fbs | restecg, exang, trestbps, age, thalach)
# (sex _|_ heartdisease, thalach | restecg, fbs, trestbps, chol, age)
# (sex _|_ heartdisease | restecg, fbs, trestbps, chol, thalach)
# (sex _|_ heartdisease, chol | restecg, fbs, trestbps, age, thalach)
# (sex _|_ heartdisease, fbs | restecg, trestbps, chol, age, thalach)
# (sex _|_ heartdisease, thalach, restecg | exang, fbs, trestbps, chol, age)
# (sex _|_ heartdisease, restecg | exang, fbs, trestbps, chol, thalach)
# (sex _|_ heartdisease, restecg, chol | exang, fbs, trestbps, age, thalach)
# (sex _|_ heartdisease, restecg, fbs | exang, trestbps, chol, age, thalach)
# (sex _|_ heartdisease, restecg | fbs, trestbps, chol, age, thalach)
# (sex _|_ thalach | heartdisease, restecg, exang, fbs, trestbps, chol)
# (sex _|_ chol, thalach | heartdisease, restecg, exang, fbs, trestbps, age)
# (sex _|_ chol | heartdisease, restecg, exang, fbs, trestbps, thalach)
# (sex _|_ thalach | heartdisease, restecg, exang, fbs, chol, age)
# (sex _|_ chol | heartdisease, restecg, exang, fbs, age, thalach)
# (sex _|_ fbs, thalach | heartdisease, restecg, exang, trestbps, chol, age)
# (sex _|_ fbs, chol | heartdisease, restecg, exang, trestbps, age, thalach)
# (sex _|_ thalach | heartdisease, restecg, fbs, trestbps, chol, age)
# (sex _|_ chol | heartdisease, restecg, fbs, trestbps, age, thalach)
# (sex _|_ fbs | heartdisease, restecg, trestbps, chol, age, thalach)
# (sex _|_ thalach, restecg | heartdisease, exang, fbs, trestbps, chol, age)
# (sex _|_ restecg | heartdisease, exang, fbs, trestbps, chol, thalach)
# (sex _|_ chol, restecg | heartdisease, exang, fbs, trestbps, age, thalach)
# (sex _|_ restecg | heartdisease, exang, fbs, chol, age, thalach)
# (sex _|_ fbs, restecg | heartdisease, exang, trestbps, chol, age, thalach)
# (sex _|_ restecg | heartdisease, fbs, trestbps, chol, age, thalach)
# (sex _|_ heartdisease, thalach | restecg, exang, fbs, trestbps, chol, age)
# (sex _|_ heartdisease | restecg, exang, fbs, trestbps, chol, thalach)
# (sex _|_ heartdisease, chol | restecg, exang, fbs, trestbps, age, thalach)
# (sex _|_ heartdisease, fbs | restecg, exang, trestbps, chol, age, thalach)
# (sex _|_ heartdisease | restecg, fbs, trestbps, chol, age, thalach)
# (sex _|_ heartdisease, restecg | exang, fbs, trestbps, chol, age, thalach)
# (sex _|_ thalach | heartdisease, restecg, exang, fbs, trestbps, chol, age)
# (sex _|_ chol | heartdisease, restecg, exang, fbs, trestbps, age, thalach)
# (sex _|_ fbs | heartdisease, restecg, exang, trestbps, chol, age, thalach)
# (sex _|_ restecg | heartdisease, exang, fbs, trestbps, chol, age, thalach)
# (sex _|_ heartdisease | restecg, exang, fbs, trestbps, chol, age, thalach)
# (exang _|_ fbs, age, sex)
# (exang _|_ fbs, age | sex)
# (exang _|_ chol, thalach, restecg | heartdisease)
# (exang _|_ age, sex | fbs)
# (exang _|_ fbs, sex | age)
# (exang _|_ chol, thalach, restecg | heartdisease, sex)
# (exang _|_ age | fbs, sex)
# (exang _|_ fbs | age, sex)
# (exang _|_ chol, thalach | heartdisease, restecg)
# (exang _|_ chol, thalach, restecg | heartdisease, fbs)
# (exang _|_ chol, thalach, restecg | heartdisease, trestbps)
# (exang _|_ thalach, restecg | heartdisease, chol)
# (exang _|_ chol, thalach, restecg | heartdisease, age)
# (exang _|_ chol, restecg | heartdisease, thalach)
# (exang _|_ heartdisease, thalach, restecg, chol | fbs, trestbps)
# (exang _|_ sex | fbs, age)
# (exang _|_ fbs, heartdisease, thalach, restecg, chol | age, trestbps)
# (exang _|_ chol, thalach | heartdisease, sex, restecg)
# (exang _|_ chol, thalach, restecg | heartdisease, sex, fbs)
# (exang _|_ chol, thalach, restecg | heartdisease, trestbps, sex)
# (exang _|_ thalach, restecg | heartdisease, sex, chol)
# (exang _|_ chol, thalach, restecg | heartdisease, age, sex)
# (exang _|_ chol, restecg | heartdisease, thalach, sex)
# (exang _|_ heartdisease, thalach, restecg, chol | fbs, trestbps, sex)
# (exang _|_ fbs, heartdisease, thalach, restecg, chol | age, trestbps, sex)
# (exang _|_ chol, thalach | heartdisease, restecg, fbs)
# (exang _|_ chol, thalach | heartdisease, trestbps, restecg)
# (exang _|_ thalach | heartdisease, restecg, chol)
# (exang _|_ chol, thalach | heartdisease, age, restecg)
# (exang _|_ chol | heartdisease, thalach, restecg)
# (exang _|_ chol, thalach, restecg | heartdisease, trestbps, fbs)
# (exang _|_ thalach, restecg | heartdisease, chol, fbs)
# (exang _|_ chol, thalach, restecg | heartdisease, age, fbs)
# (exang _|_ chol, restecg | heartdisease, thalach, fbs)
# (exang _|_ thalach, restecg | heartdisease, trestbps, chol)
# (exang _|_ fbs, thalach, restecg, chol | heartdisease, age, trestbps)
# (exang _|_ chol, restecg | heartdisease, trestbps, thalach)
# (exang _|_ thalach, restecg | heartdisease, age, chol)
# (exang _|_ restecg | heartdisease, thalach, chol)
# (exang _|_ chol, restecg | heartdisease, age, thalach)
# (exang _|_ heartdisease, thalach, chol | fbs, trestbps, restecg)
# (exang _|_ heartdisease, chol, thalach, fbs | age, trestbps, restecg)
# (exang _|_ heartdisease, thalach, restecg | fbs, trestbps, chol)
# (exang _|_ heartdisease, thalach, restecg, chol | fbs, age, trestbps)
# (exang _|_ heartdisease, restecg, chol | fbs, trestbps, thalach)
# (exang _|_ heartdisease, thalach, restecg, fbs | chol, age, trestbps)
# (exang _|_ heartdisease, chol, restecg, fbs | age, trestbps, thalach)
# (exang _|_ chol, thalach | heartdisease, sex, fbs, restecg)
# (exang _|_ chol, thalach | heartdisease, trestbps, sex, restecg)
# (exang _|_ thalach | heartdisease, sex, chol, restecg)
# (exang _|_ chol, thalach | heartdisease, age, sex, restecg)
# (exang _|_ chol | heartdisease, thalach, sex, restecg)
# (exang _|_ chol, thalach, restecg | heartdisease, trestbps, sex, fbs)
# (exang _|_ thalach, restecg | heartdisease, chol, sex, fbs)
# (exang _|_ chol, thalach, restecg | heartdisease, age, sex, fbs)
# (exang _|_ chol, restecg | heartdisease, thalach, sex, fbs)
# (exang _|_ thalach, restecg | heartdisease, trestbps, sex, chol)
# (exang _|_ fbs, thalach, chol, restecg | heartdisease, age, trestbps, sex)
# (exang _|_ chol, restecg | heartdisease, trestbps, thalach, sex)
# (exang _|_ thalach, restecg | heartdisease, age, sex, chol)
# (exang _|_ restecg | heartdisease, thalach, sex, chol)
# (exang _|_ chol, restecg | heartdisease, age, thalach, sex)
# (exang _|_ heartdisease, thalach, chol | fbs, trestbps, sex, restecg)
# (exang _|_ heartdisease, thalach, chol, fbs | age, trestbps, sex, restecg)
# (exang _|_ heartdisease, thalach, restecg | fbs, trestbps, sex, chol)
# (exang _|_ heartdisease, thalach, chol, restecg | fbs, age, trestbps, sex)
# (exang _|_ heartdisease, restecg, chol | fbs, trestbps, thalach, sex)
# (exang _|_ heartdisease, thalach, fbs, restecg | chol, age, trestbps, sex)
# (exang _|_ heartdisease, restecg, chol, fbs | age, trestbps, thalach, sex)
# (exang _|_ chol, thalach | heartdisease, trestbps, restecg, fbs)
# (exang _|_ thalach | heartdisease, chol, restecg, fbs)
# (exang _|_ chol, thalach | heartdisease, age, restecg, fbs)
# (exang _|_ chol | heartdisease, thalach, restecg, fbs)
# (exang _|_ thalach | heartdisease, trestbps, restecg, chol)
# (exang _|_ fbs, thalach, chol | heartdisease, age, trestbps, restecg)
# (exang _|_ chol | heartdisease, trestbps, thalach, restecg)
# (exang _|_ thalach | heartdisease, age, restecg, chol)
# (exang _|_ chol | heartdisease, age, thalach, restecg)
# (exang _|_ thalach, restecg | heartdisease, trestbps, chol, fbs)
# (exang _|_ chol, thalach, restecg | heartdisease, age, trestbps, fbs)
# (exang _|_ chol, restecg | heartdisease, trestbps, thalach, fbs)
# (exang _|_ thalach, restecg | heartdisease, age, chol, fbs)
# (exang _|_ restecg | heartdisease, chol, thalach, fbs)
# (exang _|_ chol, restecg | heartdisease, age, thalach, fbs)
# (exang _|_ fbs, thalach, restecg | heartdisease, age, trestbps, chol)
# (exang _|_ restecg | heartdisease, trestbps, thalach, chol)
# (exang _|_ fbs, restecg, chol | heartdisease, age, trestbps, thalach)
# (exang _|_ restecg | heartdisease, age, thalach, chol)
# (exang _|_ heartdisease, thalach | fbs, trestbps, restecg, chol)
# (exang _|_ heartdisease, thalach, chol | fbs, age, trestbps, restecg)
# (exang _|_ heartdisease, chol | fbs, trestbps, thalach, restecg)
# (exang _|_ heartdisease, thalach, fbs | chol, age, trestbps, restecg)
# (exang _|_ heartdisease, chol, fbs | age, trestbps, thalach, restecg)
# (exang _|_ heartdisease, thalach, restecg | fbs, age, trestbps, chol)
# (exang _|_ heartdisease, restecg | fbs, trestbps, thalach, chol)
# (exang _|_ heartdisease, restecg, chol | fbs, age, trestbps, thalach)
# (exang _|_ heartdisease, restecg, fbs | chol, age, trestbps, thalach)
# (exang _|_ chol, thalach | sex, heartdisease, restecg, fbs, trestbps)
# (exang _|_ thalach | sex, heartdisease, restecg, fbs, chol)
# (exang _|_ chol, thalach | sex, heartdisease, restecg, fbs, age)
# (exang _|_ chol | sex, heartdisease, restecg, fbs, thalach)
# (exang _|_ thalach | sex, heartdisease, restecg, trestbps, chol)
# (exang _|_ fbs, thalach, chol | sex, heartdisease, restecg, trestbps, age)
# (exang _|_ chol | sex, heartdisease, restecg, trestbps, thalach)
# (exang _|_ thalach | sex, heartdisease, restecg, chol, age)
# (exang _|_ chol | sex, heartdisease, restecg, age, thalach)
# (exang _|_ thalach, restecg | sex, heartdisease, fbs, trestbps, chol)
# (exang _|_ chol, thalach, restecg | sex, heartdisease, fbs, trestbps, age)
# (exang _|_ chol, restecg | sex, heartdisease, fbs, trestbps, thalach)
# (exang _|_ thalach, restecg | sex, heartdisease, fbs, chol, age)
# (exang _|_ restecg | sex, heartdisease, fbs, chol, thalach)
# (exang _|_ chol, restecg | sex, heartdisease, fbs, age, thalach)
# (exang _|_ fbs, thalach, restecg | sex, heartdisease, trestbps, chol, age)
# (exang _|_ restecg | sex, heartdisease, trestbps, chol, thalach)
# (exang _|_ fbs, restecg, chol | sex, heartdisease, trestbps, age, thalach)
# (exang _|_ restecg | sex, heartdisease, chol, age, thalach)
# (exang _|_ heartdisease, thalach | sex, restecg, fbs, trestbps, chol)
# (exang _|_ heartdisease, thalach, chol | sex, restecg, fbs, trestbps, age)
# (exang _|_ heartdisease, chol | sex, restecg, fbs, trestbps, thalach)
# (exang _|_ heartdisease, thalach, fbs | sex, restecg, trestbps, chol, age)
# (exang _|_ heartdisease, chol, fbs | sex, restecg, trestbps, age, thalach)
# (exang _|_ heartdisease, thalach, restecg | sex, fbs, trestbps, chol, age)
# (exang _|_ heartdisease, restecg | sex, fbs, trestbps, chol, thalach)
# (exang _|_ heartdisease, restecg, chol | sex, fbs, trestbps, age, thalach)
# (exang _|_ heartdisease, restecg, fbs | sex, trestbps, chol, age, thalach)
# (exang _|_ thalach | heartdisease, restecg, fbs, trestbps, chol)
# (exang _|_ chol, thalach | heartdisease, restecg, fbs, trestbps, age)
# (exang _|_ chol | heartdisease, restecg, fbs, trestbps, thalach)
# (exang _|_ thalach | heartdisease, restecg, fbs, chol, age)
# (exang _|_ chol | heartdisease, restecg, fbs, age, thalach)
# (exang _|_ fbs, thalach | heartdisease, restecg, trestbps, chol, age)
# (exang _|_ fbs, chol | heartdisease, restecg, trestbps, age, thalach)
# (exang _|_ thalach, restecg | heartdisease, fbs, trestbps, chol, age)
# (exang _|_ restecg | heartdisease, fbs, trestbps, chol, thalach)
# (exang _|_ chol, restecg | heartdisease, fbs, trestbps, age, thalach)
# (exang _|_ restecg | heartdisease, fbs, chol, age, thalach)
# (exang _|_ fbs, restecg | heartdisease, trestbps, chol, age, thalach)
# (exang _|_ heartdisease, thalach | restecg, fbs, trestbps, chol, age)
# (exang _|_ heartdisease | restecg, fbs, trestbps, chol, thalach)
# (exang _|_ heartdisease, chol | restecg, fbs, trestbps, age, thalach)
# (exang _|_ heartdisease, fbs | restecg, trestbps, chol, age, thalach)
# (exang _|_ heartdisease, restecg | fbs, trestbps, chol, age, thalach)
# (exang _|_ thalach | sex, heartdisease, restecg, fbs, trestbps, chol)
# (exang _|_ chol, thalach | sex, heartdisease, restecg, fbs, trestbps, age)
# (exang _|_ chol | sex, heartdisease, restecg, fbs, trestbps, thalach)
# (exang _|_ thalach | sex, heartdisease, restecg, fbs, chol, age)
# (exang _|_ chol | sex, heartdisease, restecg, fbs, age, thalach)
# (exang _|_ fbs, thalach | sex, heartdisease, restecg, trestbps, chol, age)
# (exang _|_ fbs, chol | sex, heartdisease, restecg, trestbps, age, thalach)
# (exang _|_ thalach, restecg | sex, heartdisease, fbs, trestbps, chol, age)
# (exang _|_ restecg | sex, heartdisease, fbs, trestbps, chol, thalach)
# (exang _|_ chol, restecg | sex, heartdisease, fbs, trestbps, age, thalach)
# (exang _|_ restecg | sex, heartdisease, fbs, chol, age, thalach)
# (exang _|_ fbs, restecg | sex, heartdisease, trestbps, chol, age, thalach)
# (exang _|_ heartdisease, thalach | sex, restecg, fbs, trestbps, chol, age)
# (exang _|_ heartdisease | sex, restecg, fbs, trestbps, chol, thalach)
# (exang _|_ heartdisease, chol | sex, restecg, fbs, trestbps, age, thalach)
# (exang _|_ heartdisease, fbs | sex, restecg, trestbps, chol, age, thalach)
# (exang _|_ heartdisease, restecg | sex, fbs, trestbps, chol, age, thalach)
# (exang _|_ thalach | heartdisease, restecg, fbs, trestbps, chol, age)
# (exang _|_ chol | heartdisease, restecg, fbs, trestbps, age, thalach)
# (exang _|_ fbs | heartdisease, restecg, trestbps, chol, age, thalach)
# (exang _|_ restecg | heartdisease, fbs, trestbps, chol, age, thalach)
# (exang _|_ heartdisease | restecg, fbs, trestbps, chol, age, thalach)
# (exang _|_ thalach | sex, heartdisease, restecg, fbs, trestbps, chol, age)
# (exang _|_ chol | sex, heartdisease, restecg, fbs, trestbps, age, thalach)
# (exang _|_ fbs | sex, heartdisease, restecg, trestbps, chol, age, thalach)
# (exang _|_ restecg | sex, heartdisease, fbs, trestbps, chol, age, thalach)
# (exang _|_ heartdisease | sex, restecg, fbs, trestbps, chol, age, thalach)
# (heartdisease _|_ age, sex, exang | fbs, trestbps)
# (heartdisease _|_ sex, exang | age, trestbps)
# (heartdisease _|_ age, exang | fbs, trestbps, sex)
# (heartdisease _|_ exang | age, trestbps, sex)
# (heartdisease _|_ age, sex, exang | fbs, trestbps, restecg)
# (heartdisease _|_ sex, exang | age, trestbps, restecg)
# (heartdisease _|_ age, sex | fbs, trestbps, exang)
# (heartdisease _|_ sex | age, trestbps, exang)
# (heartdisease _|_ age, sex, exang | fbs, trestbps, chol)
# (heartdisease _|_ sex, exang | fbs, age, trestbps)
# (heartdisease _|_ age, sex, exang | fbs, trestbps, thalach)
# (heartdisease _|_ sex, exang | chol, age, trestbps)
# (heartdisease _|_ sex, exang | age, trestbps, thalach)
# (heartdisease _|_ age, exang | fbs, trestbps, sex, restecg)
# (heartdisease _|_ exang | age, trestbps, sex, restecg)
# (heartdisease _|_ age | fbs, trestbps, sex, exang)
# (heartdisease _|_ age, exang | fbs, trestbps, sex, chol)
# (heartdisease _|_ exang | fbs, age, trestbps, sex)
# (heartdisease _|_ age, exang | fbs, trestbps, thalach, sex)
# (heartdisease _|_ exang | chol, age, trestbps, sex)
# (heartdisease _|_ exang | age, trestbps, thalach, sex)
# (heartdisease _|_ age, sex | fbs, trestbps, restecg, exang)
# (heartdisease _|_ sex | age, trestbps, restecg, exang)
# (heartdisease _|_ age, sex, exang | fbs, trestbps, restecg, chol)
# ...
# (thalach _|_ fbs, trestbps, restecg | sex, heartdisease, exang, chol, age)
# (thalach _|_ age, restecg, exang | sex, heartdisease, fbs, trestbps, chol)
# (thalach _|_ chol, restecg, exang | sex, heartdisease, fbs, trestbps, age)
# (thalach _|_ trestbps, restecg, exang | sex, heartdisease, fbs, chol, age)
# (thalach _|_ fbs, restecg, exang | sex, heartdisease, trestbps, chol, age)
# (thalach _|_ age | sex, restecg, exang, fbs, trestbps)
# (thalach _|_ age, exang | sex, restecg, fbs, trestbps, chol)
# (thalach _|_ exang | sex, restecg, fbs, trestbps, age)
# (thalach _|_ exang | sex, restecg, trestbps, chol, age)
# (thalach _|_ age | sex, exang, fbs, trestbps, chol)
# (thalach _|_ exang | sex, fbs, trestbps, chol, age)
# (thalach _|_ chol, age, sex | heartdisease, restecg, exang, fbs, trestbps)
# (thalach _|_ age, trestbps, sex | heartdisease, restecg, exang, fbs, chol)
# (thalach _|_ chol, trestbps, sex | heartdisease, restecg, exang, fbs, age)
# (thalach _|_ fbs, age, sex | heartdisease, restecg, exang, trestbps, chol)
# (thalach _|_ fbs, sex, chol | heartdisease, restecg, exang, trestbps, age)
# (thalach _|_ fbs, trestbps, sex | heartdisease, restecg, exang, chol, age)
# (thalach _|_ age, sex, exang | heartdisease, restecg, fbs, trestbps, chol)
# (thalach _|_ chol, sex, exang | heartdisease, restecg, fbs, trestbps, age)
# (thalach _|_ trestbps, sex, exang | heartdisease, restecg, fbs, chol, age)
# (thalach _|_ fbs, sex, exang | heartdisease, restecg, trestbps, chol, age)
# (thalach _|_ age, sex, restecg | heartdisease, exang, fbs, trestbps, chol)
# (thalach _|_ chol, sex, restecg | heartdisease, exang, fbs, trestbps, age)
# (thalach _|_ trestbps, sex, restecg | heartdisease, exang, fbs, chol, age)
# (thalach _|_ fbs, sex, restecg | heartdisease, exang, trestbps, chol, age)
# (thalach _|_ sex, exang, restecg | heartdisease, fbs, trestbps, chol, age)
# (thalach _|_ age, sex | restecg, exang, fbs, trestbps, chol)
# (thalach _|_ sex | restecg, exang, fbs, trestbps, age)
# (thalach _|_ sex | restecg, exang, trestbps, chol, age)
# (thalach _|_ sex, exang | restecg, fbs, trestbps, chol, age)
# (thalach _|_ sex | exang, fbs, trestbps, chol, age)
# (thalach _|_ chol, age | sex, heartdisease, restecg, exang, fbs, trestbps)
# (thalach _|_ age, trestbps | sex, heartdisease, restecg, exang, fbs, chol)
# (thalach _|_ chol, trestbps | sex, heartdisease, restecg, exang, fbs, age)
# (thalach _|_ fbs, age | sex, heartdisease, restecg, exang, trestbps, chol)
# (thalach _|_ fbs, chol | sex, heartdisease, restecg, exang, trestbps, age)
# (thalach _|_ fbs, trestbps | sex, heartdisease, restecg, exang, chol, age)
# (thalach _|_ age, exang | sex, heartdisease, restecg, fbs, trestbps, chol)
# (thalach _|_ chol, exang | sex, heartdisease, restecg, fbs, trestbps, age)
# (thalach _|_ trestbps, exang | sex, heartdisease, restecg, fbs, chol, age)
# (thalach _|_ fbs, exang | sex, heartdisease, restecg, trestbps, chol, age)
# (thalach _|_ age, restecg | sex, heartdisease, exang, fbs, trestbps, chol)
# (thalach _|_ chol, restecg | sex, heartdisease, exang, fbs, trestbps, age)
# (thalach _|_ trestbps, restecg | sex, heartdisease, exang, fbs, chol, age)
# (thalach _|_ fbs, restecg | sex, heartdisease, exang, trestbps, chol, age)
# (thalach _|_ restecg, exang | sex, heartdisease, fbs, trestbps, chol, age)
# (thalach _|_ age | sex, restecg, exang, fbs, trestbps, chol)
# (thalach _|_ exang | sex, restecg, fbs, trestbps, chol, age)
# (thalach _|_ age, sex | heartdisease, restecg, exang, fbs, trestbps, chol)
# (thalach _|_ chol, sex | heartdisease, restecg, exang, fbs, trestbps, age)
# (thalach _|_ trestbps, sex | heartdisease, restecg, exang, fbs, chol, age)
# (thalach _|_ fbs, sex | heartdisease, restecg, exang, trestbps, chol, age)
# (thalach _|_ sex, exang | heartdisease, restecg, fbs, trestbps, chol, age)
# (thalach _|_ sex, restecg | heartdisease, exang, fbs, trestbps, chol, age)
# (thalach _|_ sex | restecg, exang, fbs, trestbps, chol, age)
# (thalach _|_ age | sex, heartdisease, restecg, exang, fbs, trestbps, chol)
# (thalach _|_ chol | sex, heartdisease, restecg, exang, fbs, trestbps, age)
# (thalach _|_ trestbps | sex, heartdisease, restecg, exang, fbs, chol, age)
# (thalach _|_ fbs | sex, heartdisease, restecg, exang, trestbps, chol, age)
# (thalach _|_ exang | sex, heartdisease, restecg, fbs, trestbps, chol, age)
# (thalach _|_ restecg | sex, heartdisease, exang, fbs, trestbps, chol, age)
# (thalach _|_ sex | heartdisease, restecg, exang, fbs, trestbps, chol, age)
# (chol _|_ fbs, trestbps, sex, age, thalach, restecg, exang | heartdisease)
# (chol _|_ fbs, trestbps, age, thalach, restecg, exang | heartdisease, sex)
# (chol _|_ fbs, trestbps, sex, age, thalach, exang | heartdisease, restecg)
# (chol _|_ fbs, trestbps, sex, age, thalach, restecg | heartdisease, exang)
# (chol _|_ trestbps, sex, age, thalach, restecg, exang | heartdisease, fbs)
# (chol _|_ fbs, sex, age, thalach, restecg, exang | heartdisease, trestbps)
# (chol _|_ fbs, trestbps, sex, thalach, restecg, exang | heartdisease, age)
# (chol _|_ fbs, trestbps, sex, age, restecg, exang | heartdisease, thalach)
# (chol _|_ age, sex, exang | fbs, trestbps)
# (chol _|_ sex, exang | age, trestbps)
# (chol _|_ fbs, trestbps, age, thalach, exang | heartdisease, sex, restecg)
# (chol _|_ fbs, trestbps, age, thalach, restecg | heartdisease, sex, exang)
# (chol _|_ trestbps, age, thalach, restecg, exang | heartdisease, sex, fbs)
# (chol _|_ fbs, age, thalach, restecg, exang | heartdisease, trestbps, sex)
# (chol _|_ fbs, trestbps, thalach, restecg, exang | heartdisease, age, sex)
# (chol _|_ fbs, trestbps, age, restecg, exang | heartdisease, thalach, sex)
# (chol _|_ age, exang | fbs, trestbps, sex)
# (chol _|_ exang | age, trestbps, sex)
# (chol _|_ fbs, trestbps, sex, age, thalach | heartdisease, restecg, exang)
# (chol _|_ trestbps, sex, age, thalach, exang | heartdisease, restecg, fbs)
# (chol _|_ fbs, sex, age, thalach, exang | heartdisease, trestbps, restecg)
# (chol _|_ fbs, trestbps, sex, thalach, exang | heartdisease, age, restecg)
# (chol _|_ fbs, trestbps, sex, age, exang | heartdisease, thalach, restecg)
# (chol _|_ trestbps, sex, age, thalach, restecg | heartdisease, exang, fbs)
# (chol _|_ fbs, sex, age, thalach, restecg | heartdisease, trestbps, exang)
# (chol _|_ fbs, trestbps, sex, thalach, restecg | heartdisease, age, exang)
# (chol _|_ fbs, trestbps, sex, age, restecg | heartdisease, thalach, exang)
# (chol _|_ sex, age, thalach, restecg, exang | heartdisease, trestbps, fbs)
# (chol _|_ trestbps, sex, thalach, restecg, exang | heartdisease, age, fbs)
# (chol _|_ trestbps, sex, age, restecg, exang | heartdisease, thalach, fbs)
# (chol _|_ fbs, sex, thalach, restecg, exang | heartdisease, age, trestbps)
# (chol _|_ fbs, sex, age, restecg, exang | heartdisease, trestbps, thalach)
# (chol _|_ fbs, trestbps, sex, restecg, exang | heartdisease, age, thalach)
# (chol _|_ age, sex, exang | fbs, trestbps, restecg)
# (chol _|_ sex, exang | age, trestbps, restecg)
# (chol _|_ age, sex | fbs, trestbps, exang)
# (chol _|_ sex | age, trestbps, exang)
# (chol _|_ sex, exang | fbs, age, trestbps)
# (chol _|_ age, sex, exang | fbs, trestbps, thalach)
# (chol _|_ sex, exang | age, trestbps, thalach)
# (chol _|_ fbs, age, trestbps, thalach | heartdisease, sex, exang, restecg)
# (chol _|_ age, trestbps, thalach, exang | heartdisease, sex, fbs, restecg)
# (chol _|_ fbs, age, thalach, exang | heartdisease, trestbps, sex, restecg)
# (chol _|_ fbs, trestbps, thalach, exang | heartdisease, age, sex, restecg)
# (chol _|_ fbs, age, trestbps, exang | heartdisease, thalach, sex, restecg)
# (chol _|_ age, trestbps, thalach, restecg | heartdisease, sex, exang, fbs)
# (chol _|_ fbs, age, thalach, restecg | heartdisease, trestbps, sex, exang)
# (chol _|_ fbs, trestbps, thalach, restecg | heartdisease, age, sex, exang)
# (chol _|_ fbs, age, trestbps, restecg | heartdisease, thalach, sex, exang)
# (chol _|_ age, thalach, exang, restecg | heartdisease, trestbps, sex, fbs)
# (chol _|_ trestbps, thalach, exang, restecg | heartdisease, age, sex, fbs)
# (chol _|_ age, trestbps, restecg, exang | heartdisease, thalach, sex, fbs)
# (chol _|_ fbs, thalach, exang, restecg | heartdisease, age, trestbps, sex)
# (chol _|_ fbs, age, restecg, exang | heartdisease, trestbps, thalach, sex)
# (chol _|_ fbs, trestbps, restecg, exang | heartdisease, age, thalach, sex)
# (chol _|_ age, exang | fbs, trestbps, sex, restecg)
# (chol _|_ exang | age, trestbps, sex, restecg)
# (chol _|_ age | fbs, trestbps, sex, exang)
# (chol _|_ exang | fbs, age, trestbps, sex)
# (chol _|_ age, exang | fbs, trestbps, thalach, sex)
# (chol _|_ exang | age, trestbps, thalach, sex)
# (chol _|_ age, trestbps, sex, thalach | heartdisease, restecg, exang, fbs)
# (chol _|_ fbs, age, sex, thalach | heartdisease, trestbps, restecg, exang)
# (chol _|_ fbs, trestbps, sex, thalach | heartdisease, age, restecg, exang)
# (chol _|_ fbs, age, trestbps, sex | heartdisease, thalach, restecg, exang)
# (chol _|_ age, sex, thalach, exang | heartdisease, trestbps, restecg, fbs)
# (chol _|_ trestbps, sex, thalach, exang | heartdisease, age, restecg, fbs)
# (chol _|_ age, trestbps, sex, exang | heartdisease, thalach, restecg, fbs)
# (chol _|_ fbs, sex, thalach, exang | heartdisease, age, trestbps, restecg)
# (chol _|_ fbs, age, sex, exang | heartdisease, trestbps, thalach, restecg)
# (chol _|_ fbs, trestbps, sex, exang | heartdisease, age, thalach, restecg)
# (chol _|_ age, sex, thalach, restecg | heartdisease, trestbps, exang, fbs)
# (chol _|_ trestbps, sex, thalach, restecg | heartdisease, age, exang, fbs)
# (chol _|_ age, trestbps, sex, restecg | heartdisease, thalach, exang, fbs)
# (chol _|_ fbs, sex, thalach, restecg | heartdisease, age, trestbps, exang)
# (chol _|_ fbs, age, sex, restecg | heartdisease, trestbps, thalach, exang)
# (chol _|_ fbs, trestbps, sex, restecg | heartdisease, age, thalach, exang)
# (chol _|_ sex, thalach, exang, restecg | heartdisease, age, trestbps, fbs)
# (chol _|_ age, sex, exang, restecg | heartdisease, trestbps, thalach, fbs)
# (chol _|_ trestbps, sex, exang, restecg | heartdisease, age, thalach, fbs)
# (chol _|_ fbs, sex, exang, restecg | heartdisease, age, trestbps, thalach)
# (chol _|_ age, sex | fbs, trestbps, restecg, exang)
# (chol _|_ sex | age, trestbps, restecg, exang)
# (chol _|_ sex, exang | fbs, age, trestbps, restecg)
# (chol _|_ age, sex, exang | fbs, trestbps, thalach, restecg)
# (chol _|_ sex, exang | age, trestbps, thalach, restecg)
# (chol _|_ sex | fbs, age, trestbps, exang)
# (chol _|_ age, sex | fbs, trestbps, thalach, exang)
# (chol _|_ sex | age, trestbps, thalach, exang)
# (chol _|_ sex, exang | fbs, age, trestbps, thalach)
# (chol _|_ age, trestbps, thalach | sex, heartdisease, restecg, exang, fbs)
# (chol _|_ fbs, age, thalach | sex, heartdisease, restecg, exang, trestbps)
# (chol _|_ fbs, trestbps, thalach | sex, heartdisease, restecg, exang, age)
# (chol _|_ fbs, age, trestbps | sex, heartdisease, restecg, exang, thalach)
# (chol _|_ age, thalach, exang | sex, heartdisease, restecg, fbs, trestbps)
# (chol _|_ trestbps, thalach, exang | sex, heartdisease, restecg, fbs, age)
# (chol _|_ age, trestbps, exang | sex, heartdisease, restecg, fbs, thalach)
# (chol _|_ fbs, thalach, exang | sex, heartdisease, restecg, trestbps, age)
# (chol _|_ fbs, age, exang | sex, heartdisease, restecg, trestbps, thalach)
# (chol _|_ fbs, trestbps, exang | sex, heartdisease, restecg, age, thalach)
# (chol _|_ age, thalach, restecg | sex, heartdisease, exang, fbs, trestbps)
# (chol _|_ trestbps, thalach, restecg | sex, heartdisease, exang, fbs, age)
# (chol _|_ age, trestbps, restecg | sex, heartdisease, exang, fbs, thalach)
# (chol _|_ fbs, thalach, restecg | sex, heartdisease, exang, trestbps, age)
# (chol _|_ fbs, age, restecg | sex, heartdisease, exang, trestbps, thalach)
# (chol _|_ fbs, trestbps, restecg | sex, heartdisease, exang, age, thalach)
# (chol _|_ thalach, exang, restecg | sex, heartdisease, fbs, trestbps, age)
# (chol _|_ age, restecg, exang | sex, heartdisease, fbs, trestbps, thalach)
# (chol _|_ trestbps, restecg, exang | sex, heartdisease, fbs, age, thalach)
# (chol _|_ fbs, restecg, exang | sex, heartdisease, trestbps, age, thalach)
# (chol _|_ age | sex, restecg, exang, fbs, trestbps)
# (chol _|_ exang | sex, restecg, fbs, trestbps, age)
# (chol _|_ age, exang | sex, restecg, fbs, trestbps, thalach)
# (chol _|_ exang | sex, restecg, trestbps, age, thalach)
# (chol _|_ age | sex, exang, fbs, trestbps, thalach)
# (chol _|_ exang | sex, fbs, trestbps, age, thalach)
# (chol _|_ age, sex, thalach | heartdisease, restecg, exang, fbs, trestbps)
# (chol _|_ trestbps, sex, thalach | heartdisease, restecg, exang, fbs, age)
# (chol _|_ age, trestbps, sex | heartdisease, restecg, exang, fbs, thalach)
# (chol _|_ fbs, sex, thalach | heartdisease, restecg, exang, trestbps, age)
# (chol _|_ fbs, age, sex | heartdisease, restecg, exang, trestbps, thalach)
# (chol _|_ fbs, trestbps, sex | heartdisease, restecg, exang, age, thalach)
# (chol _|_ sex, thalach, exang | heartdisease, restecg, fbs, trestbps, age)
# (chol _|_ age, sex, exang | heartdisease, restecg, fbs, trestbps, thalach)
# (chol _|_ trestbps, sex, exang | heartdisease, restecg, fbs, age, thalach)
# (chol _|_ fbs, sex, exang | heartdisease, restecg, trestbps, age, thalach)
# (chol _|_ sex, thalach, restecg | heartdisease, exang, fbs, trestbps, age)
# (chol _|_ age, sex, restecg | heartdisease, exang, fbs, trestbps, thalach)
# (chol _|_ trestbps, sex, restecg | heartdisease, exang, fbs, age, thalach)
# (chol _|_ fbs, sex, restecg | heartdisease, exang, trestbps, age, thalach)
# (chol _|_ sex, exang, restecg | heartdisease, fbs, trestbps, age, thalach)
# (chol _|_ sex | restecg, exang, fbs, trestbps, age)
# (chol _|_ age, sex | restecg, exang, fbs, trestbps, thalach)
# (chol _|_ sex | restecg, exang, trestbps, age, thalach)
# (chol _|_ sex, exang | restecg, fbs, trestbps, age, thalach)
# (chol _|_ sex | exang, fbs, trestbps, age, thalach)
# (chol _|_ age, thalach | sex, heartdisease, restecg, exang, fbs, trestbps)
# (chol _|_ trestbps, thalach | sex, heartdisease, restecg, exang, fbs, age)
# (chol _|_ age, trestbps | sex, heartdisease, restecg, exang, fbs, thalach)
# (chol _|_ fbs, thalach | sex, heartdisease, restecg, exang, trestbps, age)
# (chol _|_ fbs, age | sex, heartdisease, restecg, exang, trestbps, thalach)
# (chol _|_ fbs, trestbps | sex, heartdisease, restecg, exang, age, thalach)
# (chol _|_ thalach, exang | sex, heartdisease, restecg, fbs, trestbps, age)
# (chol _|_ age, exang | sex, heartdisease, restecg, fbs, trestbps, thalach)
# (chol _|_ trestbps, exang | sex, heartdisease, restecg, fbs, age, thalach)
# (chol _|_ fbs, exang | sex, heartdisease, restecg, trestbps, age, thalach)
# (chol _|_ thalach, restecg | sex, heartdisease, exang, fbs, trestbps, age)
# (chol _|_ age, restecg | sex, heartdisease, exang, fbs, trestbps, thalach)
# (chol _|_ trestbps, restecg | sex, heartdisease, exang, fbs, age, thalach)
# (chol _|_ fbs, restecg | sex, heartdisease, exang, trestbps, age, thalach)
# (chol _|_ restecg, exang | sex, heartdisease, fbs, trestbps, age, thalach)
# (chol _|_ age | sex, restecg, exang, fbs, trestbps, thalach)
# (chol _|_ exang | sex, restecg, fbs, trestbps, age, thalach)
# (chol _|_ sex, thalach | heartdisease, restecg, exang, fbs, trestbps, age)
# (chol _|_ age, sex | heartdisease, restecg, exang, fbs, trestbps, thalach)
# (chol _|_ trestbps, sex | heartdisease, restecg, exang, fbs, age, thalach)
# (chol _|_ fbs, sex | heartdisease, restecg, exang, trestbps, age, thalach)
# (chol _|_ sex, exang | heartdisease, restecg, fbs, trestbps, age, thalach)
# (chol _|_ sex, restecg | heartdisease, exang, fbs, trestbps, age, thalach)
# (chol _|_ sex | restecg, exang, fbs, trestbps, age, thalach)
# (chol _|_ thalach | sex, heartdisease, restecg, exang, fbs, trestbps, age)
# (chol _|_ age | sex, heartdisease, restecg, exang, fbs, trestbps, thalach)
# (chol _|_ trestbps | sex, heartdisease, restecg, exang, fbs, age, thalach)
# (chol _|_ fbs | sex, heartdisease, restecg, exang, trestbps, age, thalach)
# (chol _|_ exang | sex, heartdisease, restecg, fbs, trestbps, age, thalach)
# (chol _|_ restecg | sex, heartdisease, exang, fbs, trestbps, age, thalach)
# (chol _|_ sex | heartdisease, restecg, exang, fbs, trestbps, age, thalach)

# %%
from pgmpy.inference import VariableElimination
heartDisease_infer = VariableElimination(model)
q = heartDisease_infer.query(variables=["heartdisease"],
evidence={"age": 29})

print(q)
# Out:
# Finding Elimination Order: : 100%|██████████| 7/7 [00:00<00:00, 3508.20it/s]
# Eliminating: exang: 100%|██████████| 7/7 [00:00<00:00, 259.95it/s]
# +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              0.6630 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.3370 |
# +-----------------+---------------------+

# %%
q = heartDisease_infer.query(variables=["heartdisease"],
evidence={"chol": 100})

print(q)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pgmpy\factors\discrete\DiscreteFactor.py:438: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   warn(
# Finding Elimination Order: : 100%|██████████| 7/7 [00:00<00:00, 1400.64it/s]
# Eliminating: exang: 100%|██████████| 7/7 [00:00<00:00, 143.24it/s]
# +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              1.0000 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.0000 |
# +-----------------+---------------------+
